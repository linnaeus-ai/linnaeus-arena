# %%
system_message = """
General description: Summarize the input text.
Detailed description:
Analyze the text and detect the input language. Select the most appropriate method for summarization based on clarity, brevity, and retention of key points. Apply this method to generate a summary in the same language as the input text. Do not translate any text.

Ensure the summary maintains the key information and overall meaning of the input text. The summary should be concise and coherent, preferably limited to a few sentences or a short paragraph unless specified otherwise.

Handle any ambiguous parts of the text by summarizing the clear parts and omitting ambiguous sections without making assumptions. If the text contains multiple languages, summarize each language section separately.

Do not add any additional commentary, explanations, or niceties. Output only the summarized text in a clear and readable format.
"""

test_subjects = [
    {"model": "grok-3", "system_message": system_message, "temperature": 1.0},
    {"model": "mistral-small-2503", "system_message": system_message},
    {"model": "gpt-4o", "system_message": system_message, "temperature": 0.5},
    {"model": "gpt-4.1", "system_message": system_message},
]
