# %%
# Show database content:

import linnaeus_test.database

database = linnaeus_test.database.Database("summarization.db")
print(database.model_preset_to_json())  # Print evaluated model presets
print(database.eval_to_csv())  # Print user evaluations
