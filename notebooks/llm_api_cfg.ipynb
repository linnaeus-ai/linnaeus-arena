# %%
llm_api_cfg = {
    "gpt-4o": {
        "api": "openai",
        "url": "https://example.com/",
        "key": "<SECRET_KEY>",
        "defaults": {"temperature": 1.0, "top_p": 1.0},
    },
    "grok-3": {
        "api": "openai",
        "url": "https://example.com/",
        "key": "<SECRET_KEY>",
        "defaults": {"temperature": 1.0, "top_p": 1.0},
    },
}
llm_api_cfg["gpt-4.1"] = llm_api_cfg["gpt-4o"]
llm_api_cfg["mistral-small-2503"] = llm_api_cfg["grok-3"]
